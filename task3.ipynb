# %% [markdown]
# Author-Maitreya Kulshreshtha

# %% [markdown]
# Task 3:Exploratory Data Analysis - Retail

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import os

# %%
#Importing the dataset of SampleSuperstore.

# %%
df=pd.read_csv("SampleSuperstore.csv")

# %%
#Getting first 10 inputs from the dataset.
df.head(10)
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5  Standard Class   Consumer  United States      Los Angeles  California
# 6  Standard Class   Consumer  United States      Los Angeles  California
# 7  Standard Class   Consumer  United States      Los Angeles  California
# 8  Standard Class   Consumer  United States      Los Angeles  California
# 9  Standard Class   Consumer  United States      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# ...

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
sns.pairplot(df)

# %%
#correlation between quantities of the dataset.
df.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
sns.heatmap(df.corr(),annot=True)

# %%
#Sales vs category plot

# %%
sns.countplot(x=df['Ship Mode'])

# %%
plt.figure(figsize=(15,12))
sns.countplot(x='State',data=df,order=df['State'].value_counts().index,color='#66CDAA')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Highest no of buyers are from California and New York.

# %%
sns.pairplot(df,hue='Category')

# %%
sns.pairplot(df,hue='Ship Mode')

# %%
#analysis of sales and profit in different sub-categories.

# %%
plt.bar('Category','Sales',data=df)
plt.xlabel('Category',size=10)
plt.xlabel('Sales',size=10)
plt.title('Sales vs Category',size=10)
# Out:
# Text(0.5, 1.0, 'Sales vs Category')

# %%
plt.bar('Category','Profit',data=df)
plt.xlabel('Category',size=10)
plt.xlabel('Profit',size=10)
plt.title('Profit vs Category',size=10)
# Out:
# Text(0.5, 1.0, 'Profit vs Category')

# %%
df.max()
# Out:
# Ship Mode       Standard Class
# Segment            Home Office
# Country          United States
# City                      Yuma
# State                  Wyoming
# Postal Code              99301
# Region                    West
# Category            Technology
# Sub-Category            Tables
# Sales                  22638.5
# Quantity                    14
# Discount                   0.8
# Profit                 8399.98
# dtype: object

# %% [markdown]
# Maximum profit=8399.98
# Maximum Sales=22638.5

# %%
df.min()
# Out:
# Ship Mode         First Class
# Segment              Consumer
# Country         United States
# City                 Aberdeen
# State                 Alabama
# Postal Code              1040
# Region                Central
# Category            Furniture
# Sub-Category      Accessories
# Sales                   0.444
# Quantity                    1
# Discount                    0
# Profit               -6599.98
# dtype: object

# %% [markdown]
# Minimum profit=-6599.98
# Maximum Sales=0.444

# %%
df.hist(figsize=(10,10),bins=30)
plt.show()

# %% [markdown]
# Discount give maximum is 0 to 20 percent

# %%
plt.figure(figsize=(10,8))
df['Segment'].value_counts().plot.pie(autopct = '%1.1f%%')
plt.show()

# %%
sns.lineplot(x='Region',y='Profit',label='Profit',data=df,color='r')
plt.legend()
plt.show()

# %% [markdown]
# Regional sales visualization

# %%
sns.lineplot(x='Region',y='Sales',label='Region vs Sales',data=df,color='g')
plt.legend()
plt.show()

# %%
new = df.groupby(['Category']).Profit.sum()
new_df = pd.DataFrame(new)
new_df
# Out:
#                       Profit
# Category
# Furniture         18451.2728
# Office Supplies  122490.8008
# Technology       145454.9481

# %%
new1 = df.groupby(['Ship Mode']).Profit.sum()
new1_df = pd.DataFrame(new1)
new1_df
# Out:
#                      Profit
# Ship Mode
# First Class      48969.8399
# Same Day         15891.7589
# Second Class     57446.6354
# Standard Class  164088.7875

# %% [markdown]
# So Standard class ship mode has the maximum profit and
# Technology category is the most promising.

# %% [markdown]
# Regionally central part is worst and western region generates highest profit.
